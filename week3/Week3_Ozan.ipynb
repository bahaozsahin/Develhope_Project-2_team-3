# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../week2/cleaned_playstore.csv", index_col=0)

# %% [markdown]
# ### Week 3 Task 1
# Task Desciption: Team should find top 5 applications and criteria is that apps should have the smallest size (MB) but highest number of installs. The idea is to show that small apps don't necessarily have small number of installs. This has to be done on whole dataset (no need to split into any category).
#
# Best way to do this task is to scatterplot size by installs.

# %%
sns.scatterplot(data=df, x="Installs", y="Size")
plt.show()

# %% [markdown]
# As we can see thee ae two apps with 1e9 installs and size around 0.2 x 1e8 mb.

# %%
df[df.Installs == 1000000000]
# Out:
#                                            App             Category  Rating  \
# 152                          Google Play Books  BOOKS_AND_REFERENCE     3.9
# 299   Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 300                         WhatsApp Messenger        COMMUNICATION     4.4
# 302               Google Chrome: Fast & Secure        COMMUNICATION     4.3
# 304                                      Gmail        COMMUNICATION     4.3
# 305                                   Hangouts        COMMUNICATION     4.0
# 349              Skype - free IM & video calls        COMMUNICATION     4.1
# 701                          Google Play Games        ENTERTAINMENT     4.3
# 1356                            Subway Surfers                 GAME     4.5
# 2002                                  Facebook               SOCIAL     4.1
# 2003                                 Instagram               SOCIAL     4.5
# ...

# %%
df
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9655                                   Sya9a Maroc - FR               FAMILY
# 9656                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 9657                             Parkinson Exercices FR              MEDICAL
# 9658                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9659      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...
