# %%
import pandas as pd
data = pd.read_csv('../week2/cleaned_playstore.csv', index_col=0)
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews          Size  Installs  Type  Price Content Rating
# 0      159  1.900000e+07     10000  Free    0.0       Everyone
# 1      967  1.400000e+07    500000  Free    0.0       Everyone
# 2    87510  8.700000e+06   5000000  Free    0.0       Everyone
# 3   215644  2.500000e+07  50000000  Free    0.0           Teen
# 4      967  2.800000e+06    100000  Free    0.0       Everyone

# %% [markdown]
# ### Task 1:
# Find if there is a correlation between the price of the apps and the Content Rating (Teen, Everyone, Mature. etc).

# %%
df = pd.DataFrame(data)

# %%
corr = df['Content Rating'].str.get_dummies().corrwith(df.Price)

# %%
corr # this shows that Content Rating is not correlated with Price
# Out:
# Adults only 18+   -0.001150
# Everyone           0.016444
# Everyone 10+      -0.007333
# Mature 17+        -0.010259
# Teen              -0.009582
# Unrated           -0.000939
# dtype: float64

# %% [markdown]
# ### Task 2:
# Find the sentiment of all apps using np files and "afinn" lib

# %% [markdown]
# #### NP files

# %%
n = list(pd.read_excel('n.xlsx', header = None)[0])
p = list(pd.read_excel('p.xlsx', header = None)[0])
review = pd.read_csv('../week2/cleaned_playstore_reviews.csv', index_col = 0)

# %%
review.drop(columns= ['Sentiment', 'Sentiment_Polarity', 'Sentiment_Subjectivity'], inplace=True)

# %%
import re
Sentiment_score = []
for i in review['Translated_Review'].str.lower():
    score = 0
    sentence = re.sub('[^A-Za-z0-9 ]+', '', i)
    words = sentence.split()
    for word in words:
        if word in p:
            score += 1
        elif word in n:
            score -= 1
        else:
            continue
    Sentiment_score.append(score)
review['Sentiment NP'] = Sentiment_score

# %%
review.head()
# Out:
#                                 App  \
# 0             10 Best Foods for You
# 1  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 2                              11st
# 3        1800 Contacts - Lens Store
# 4   1LINE – One Line with One Touch
#
#                                    Translated_Review  Sentiment NP
# 0  I like eat delicious food. That's I'm cooking ...             4
# 1                                              Great             1
# 2                           Horrible ID verification            -1
# 3  Great hassle free way order contacts. Got call...             1
# 4  gets 1* there's ad every single level restart,...            -1

# %% [markdown]
# #### Afinn lib

# %%
from afinn import Afinn

# %%
afn = Afinn()
scores = [afn.score(r) for r in review['Translated_Review']]
review['Sentiment Afinn'] = scores

# %%
review.head()
# Out:
#                                 App  \
# 0             10 Best Foods for You
# 1  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 2                              11st
# 3        1800 Contacts - Lens Store
# 4   1LINE – One Line with One Touch
#
#                                    Translated_Review  Sentiment NP  \
# 0  I like eat delicious food. That's I'm cooking ...             4
# 1                                              Great             1
# 2                           Horrible ID verification            -1
# 3  Great hassle free way order contacts. Got call...             1
# 4  gets 1* there's ad every single level restart,...            -1
#
#    Sentiment Afinn
# 0             13.0
# 1              3.0
# 2             -3.0
# 3              4.0
# 4             -2.0

# %% [markdown]
# ### Task 3
# for Free apps only list the top 5 highest and lowest sentiment numbers for afinn column with the name of the app and the app category (this task was supposed to be done for paid apps only but it's changed to Free apps only)

# %%
merged_df = pd.merge(review, df, on='App') # This will join tables with inner join on App column.

# %%
review.shape
# Out:
# (641, 4)

# %%
merged_df.shape # here we can see there is difference in number of rows between merged dataframe and review dataframe.
# Out:
# (609, 12)

# %%
review_test = merged_df.drop(columns=['Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating'])

# %%
pd.concat([review, review_test]).drop_duplicates(keep=False) # these are the apps that are missing in "cleaned playstore.csv"
# Out:
#                                                    App  \
# 1                     104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 14   591房屋交易-租屋、中古屋、新建案、實價登錄、別墅透天、公寓套房、捷運、買房賣房行情、房價...
# 15                                          591房屋交易-香港
# 90                         Aprender inglés con Wlingua
# 118                BaBe Lite - Baca Berita Hemat Kuota
# 131                           Bagan - Myanmar Keyboard
# 132                                         Banco Itaú
# 133                                    Banco do Brasil
# 134                                     Bancomer móvil
# 136                     Bangla Newspaper – Prothom Alo
# 141                                   Banque Populaire
# 174                        Birdays – Birthday reminder
# 197                 Brasileirão Pro 2018 - Série A e B
# 208                                  Buienradar - weer
# 210                       Bukalapak - Jual Beli Online
# 216                     BÁO MỚI - Đọc Báo, Tin Tức 24h
# 219                                              CAIXA
# 275                                              Claro
# 282                     ColorFil - Adult Coloring Book
# 317                             Curso de Ingles Gratis
# 318                                     Cut the Rope 2
# 323               DELISH KITCHEN - 無料レシピ動画で料理を楽しく・簡単に！
# 334                      Despegar.com Hoteles y Vuelos
# 335                         Detector de Radares Gratis
# 341                        Die TK-App – alles im Griff
# 346                                            Dil Mil
# 355     Domofond Недвижимость. Купить, снять квартиру.
# 361                             Dr. Oetker Rezeptideen
# 394                                 El tiempo de AEMET
# 397                              Enterprise Rent-A-Car
# 480   Foot Mercato : transferts, résultats, news, live
# 624                     Home Street – Home Design Game
#
#                                      Translated_Review  Sentiment NP  \
# 1                                                Great             1
# 14                          This good searching house.             1
# 15   1. Look filtering criteria 2. Better store fil...             1
# 90   A very good application, that's just the words...             1
# 118                                  Great information             1
# 131  Then updated hands-room, though, it hit the ke...            -1
# 132  The new Itaú has gotten better on the one hand...             2
# 133  Lol, from Brazil bank are a joke. To what appl...            -3
# 134  I thought it was a mistake, but it turns out t...            -2
# 136  Develop app. It's slow. It takes much time vie...            -2
# 141  For a while now I just can not access my accou...            -1
# 174  So entered self... I liked old days, Facebook ...             0
# 197  Until it's good, BUT WHEN WILL UPDATE THE MENG...             1
# 208  Please please consider adding English language...             1
# 210  Protection against sellers is lacking. When th...            -3
# 216  There are really bad days with the quality of ...            -1
# 219  Good afternoon, I'm grateful that you've answe...            -2
# 275  Terrible app, monopolizes a lot of space, is s...            -3
# 282  It's great but... I would like added way make ...             1
# 317  One of the best applications to learn English ...             6
# 318  I hate games penalize playing them, every 3 ru...            -1
# 323  Everything looks delicious, it's just recipes ...             2
# 334  Application is nice but problem starts when yo...             0
# 335                                          Hits good             1
# 341  The fingerprint login works unreliable Pixel p...             0
# 346                       As glitchy Indian government             0
# 355  I would like more filters to search. For examp...             1
# 361  Sadly ingredient lists missing recipes. Also I...             2
# 394  It keeps closing when a time passes, you look ...             0
# 397  A nice, clean overall experience app. There tw...             4
# 480   Awesome. Scores updated immediately. Hope fixed.             1
# 624  Can't say enough great stuff game. I get much ...             4
#
#      Sentiment Afinn
# 1                3.0
# 14               3.0
# 15               2.0
# 90               3.0
# 118              3.0
# 131             -2.0
# 132              5.0
# 133              0.0
# 134              4.0
# 136             -2.0
# 141             -1.0
# 174             -1.0
# 197              3.0
# 208              4.0
# 210            -10.0
# 216             -4.0
# 219              1.0
# 275             -6.0
# 282              8.0
# 317             11.0
# 318             -6.0
# 323              7.0
# 334              2.0
# 335              3.0
# 341              0.0
# 346              0.0
# 355              2.0
# 361              2.0
# 394              0.0
# 397             11.0
# 480              6.0
# 624              9.0

# %%
merged_df.drop(columns=['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'Content Rating', 'Sentiment NP', 'Translated_Review'], inplace=True)

# %%
merged_df = merged_df[merged_df.Type != 'Paid'].drop(columns='Type')

# %%
merged_df = merged_df[['App', 'Category', 'Sentiment Afinn']].reset_index().drop(columns=['index'])

# %%
merged_df
# Out:
#                                                    App            Category  \
# 0                                10 Best Foods for You  HEALTH_AND_FITNESS
# 1                                                 11st            SHOPPING
# 2                           1800 Contacts - Lens Store             MEDICAL
# 3                      1LINE – One Line with One Touch                GAME
# 4     2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif     PERSONALIZATION
# ..                                                 ...                 ...
# 596                      Hotels Combined - Cheap deals    TRAVEL_AND_LOCAL
# 597  Hotels.com: Book Hotel Rooms & Find Vacation D...    TRAVEL_AND_LOCAL
# 598     Hotspot Shield Free VPN Proxy & Wi-Fi Security               TOOLS
# 599                                            Hotstar       ENTERTAINMENT
# 600                     Housing-Real Estate & Property           LIFESTYLE
#
#      Sentiment Afinn
# 0               13.0
# 1               -3.0
# 2                4.0
# 3               -2.0
# 4                4.0
# ..               ...
# 596             -3.0
# 597             -2.0
# 598             -1.0
# 599              0.0
# 600              2.0
#
# [601 rows x 3 columns]

# %%
merged_df.sort_values(by='Sentiment Afinn', ascending=False, inplace=True)

# %%
merged_df.head() # TOP 5
# Out:
#                                 App       Category  Sentiment Afinn
# 557     Hamilton — The Official App  ENTERTAINMENT             36.0
# 76                    Angry Birds 2           GAME             32.0
# 538  HBO GO: Stream with TV Package  ENTERTAINMENT             30.0
# 256                  Clash of Clans           GAME             27.0
# 315  Digit Save Money Automatically        FINANCE             26.0

# %%
merged_df.tail().sort_values(by='Sentiment Afinn') # LOW 5
# Out:
#                                                    App             Category  \
# 148  BestCam Selfie-selfie, beauty camera, photo ed...               BEAUTY
# 162                     Black People Meet Singles Date               DATING
# 203                                 CBS Sports Fantasy               SPORTS
# 401                                  FamilySearch Tree  BOOKS_AND_REFERENCE
# 176                           Booking.com Travel Deals     TRAVEL_AND_LOCAL
#
#      Sentiment Afinn
# 148            -24.0
# 162            -15.0
# 203            -14.0
# 401            -13.0
# 176            -11.0

# %%
pd.concat([merged_df.head(), merged_df.tail().sort_values(by='Sentiment Afinn')]) # TOP 5 AND LOW 5 IN SAME TABLE
# Out:
#                                                    App             Category  \
# 557                        Hamilton — The Official App        ENTERTAINMENT
# 76                                       Angry Birds 2                 GAME
# 538                     HBO GO: Stream with TV Package        ENTERTAINMENT
# 256                                     Clash of Clans                 GAME
# 315                     Digit Save Money Automatically              FINANCE
# 148  BestCam Selfie-selfie, beauty camera, photo ed...               BEAUTY
# 162                     Black People Meet Singles Date               DATING
# 203                                 CBS Sports Fantasy               SPORTS
# 401                                  FamilySearch Tree  BOOKS_AND_REFERENCE
# 176                           Booking.com Travel Deals     TRAVEL_AND_LOCAL
#
#      Sentiment Afinn
# 557             36.0
# 76              32.0
# 538             30.0
# 256             27.0
# 315             26.0
# 148            -24.0
# 162            -15.0
# 203            -14.0
# 401            -13.0
# 176            -11.0

# %% [markdown]
# ### Task 4
# what is the best category according to afinn sentiment values

# %%
merged_df.groupby(by='Category').sum(numeric_only=True).sort_values(by='Sentiment Afinn', ascending=False).head(1)
# Out:
#           Sentiment Afinn
# Category
# GAME                490.0
